# %% [markdown]
# # Testando o OpenCV
#
# Este notebook serve para verificar se a biblioteca `cv2` está instalada e
# funcionando corretamente. Execute as células abaixo para importar o OpenCV e
# mostrar sua versão. Também há um teste opcional para capturar uma imagem da
# webcam.

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img = cv2.imread('img/image.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize = (20,20))

plt.imshow(img)
plt.show()
